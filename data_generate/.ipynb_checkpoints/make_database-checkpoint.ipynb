# %%
from __future__ import print_function
from os.path import join
import time

import numpy as np
import pandas as pd
import pyxis as px
from astropy.io import fits
import matplotlib.pyplot as plt

# %% [markdown]
# #### Code exploring lognormal distribution for SNR, not used

# %%
mu, sigma = 4.5, 1.
s = np.random.lognormal(mu, sigma, 10000)
s = s[(s <= 500) & (s >= 20)]
print(s.shape)
# Out:
# (8911,)

# %%
count, bins, ignored = plt.hist(s, 100, density=True, align='mid')
x = np.linspace(min(bins), max(bins), 10000)
pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2))
       / (x * sigma * np.sqrt(2 * np.pi)))
plt.plot(x, pdf, linewidth=2, color='r')
plt.axis('tight')
plt.show()

# %% [markdown]
# #### For proof of concept just generate SNR randomly within a range

# %%
SNR_train = np.linspace(20., 250., int(5e6))
np.random.shuffle(SNR_train)
SNR_test = np.linspace(20., 250., int(5e5))
np.random.shuffle(SNR_test)

# %% [markdown]
# ### Start here to create database

# %%
def normalize(form, data, pars=None):
    '''
    Normalizes data into one of three forms:
    '01': normalize between 0 and 1, pars = (min, max)
    '-11': normalize between -1 and 1, pars = (min, max)
    'std': standardize to center around 0 with std dev of 1, pars = (mean, std)
    '''
    if form == 'std': 
        mean, std = pars if pars is not None else (data.mean(), data.std())
        new_data = (data-mean)/std
        
        return new_data
    
    else:
        min_val, max_val = pars if pars is not None else (np.min(data), np.max(data))
        
        if form == '01':
            new_data = (data - min_val)/(max_val-min_val)
            
            return new_data
        
        elif form == '-11':
            new_data = (2*data - (max_val+min_val))/(max_val-min_val)
            
            return new_data
        
        else:
            raise ValueError("Invalid form, must be '01', '-11', or 'std'.")

# %%
def add_noise(data, SNR):
    noise = np.random.normal(0, 1, data.shape)
    segmask = data > 0.1*np.max(data)
    target = np.sum(data[segmask])/SNR
    noise *= target/np.sqrt(np.sum(noise[segmask]**2))
    return data + noise

# %%
par_ranges = \
{
    'g1': [-0.1, 0.1],
    'g2': [-0.1, 0.1],
    'theta_int': [-np.pi, np.pi],
    'sini': [0, 1],
    'v0': [-30, 30],
    'vcirc': [60, 540],
    'rscale': [0.1, 10],
    'hlr': [0.1, 5],
}

img_noise_range = [-100, 150]
spec_noise_range = [-250, 250]

# %%
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_low_g/'
with fits.open(join(data_dir, f'temp_{1}/training_{0}.fits')) as hdu:

    img = hdu[7].data
    img_wnoise = add_noise(img, 15)

    specs = np.full((3, 64), 0.)
    for j in range(3):
        spec = hdu[2*j+1].data
        spec_wnoise = add_noise(spec, 15)
        specs[j, :spec.shape[0]] = spec_wnoise

# %%
plt.imshow(img_wnoise)

# %%
plt.plot(specs[0])

# %%
n = 5000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_5m/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_train_5m.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/databases/train_database_5m'
samples = pd.read_csv(samp_dir)

# %%
for i, values in enumerate(par_ranges.values()):
    samples.iloc[:, i+1] = normalize('-11', samples.iloc[:, i+1], values)
# Out:
# -0.1 0.1
# -0.1 0.1
# -3.141592653589793 3.141592653589793
# 0 1
# -30 30
# 60 540
# 0.1 10
# 0.1 5

# %%
for par, values in samples.items():
    print(np.min(values), np.max(values))
# Out:
# 0 4999999
# -0.99987336117659 0.999975047517415
# -0.999899855894996 0.999961886397742
# -0.9999998000000001 0.9999998000000001
# -0.9999998 0.9999998000000001
# -0.9999998 0.9999998000000001
# -0.9999998 0.9999998
# -0.9999998 0.9999998
# -0.9999998 0.9999998000000001

# %% [markdown]
# ### Create training database

# %%
n = 5000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_5m/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_train_5m.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/databases/train_database_5m'
samples = pd.read_csv(samp_dir)
for i, values in enumerate(par_ranges.values()):
    samples.iloc[:, i+1] = normalize('-11', samples.iloc[:, i+1], values)
samples.to_csv('/xdisk/timeifler/wxs0703/kl_nn/samples/normalized/samples_train_5m.csv', index=False)
    
with px.Writer(dirpath=save_dir, map_size_limit=200000, ram_gb_limit=8) as db:
    
    for index in range(1000):
        start = time.time()
        folder = index+1
        img_stack = np.full((n, 1, 48, 48), 0.)
        spec_stack = np.full((n, 1, 3, 64), 0.)
        start_id = index*n
        file_id = index*n
        ids = np.arange(start_id, start_id+n, dtype=np.uint64)
        SNR = SNR_train[ids]
        fids = np.array(samples.iloc[ids])[:, 1:]
        img_mean_std = np.full((1000, 2), 0.)
        spec_mean_std = np.full((1000, 2), 0.)

        for i in range(n):
            
            ID = file_id + i

            with fits.open(join(data_dir, f'temp_{folder}/training_{ID}.fits')) as hdu:

                img = hdu[4].data
                img_wnoise = add_noise(img, SNR[i])
                img_stack[i, 0] = img_wnoise
                
                specs = np.full((3, 64), 0.)
                for k in range(3):
                    spec = hdu[k+1].data
                    spec_wnoise = add_noise(spec, SNR[i])
                    specs[k, :spec.shape[0]] = spec_wnoise
                spec_stack[i, 0] = specs

        if index == 0:
            img_mean, img_std = (img_stack.mean(), img_stack.std())
            spec_mean, spec_std = (spec_stack.mean(), spec_stack.std())
        
        img_stack = normalize('std', img_stack, (img_mean, img_std))
        spec_stack = normalize('std', spec_stack, (spec_mean, spec_std))
        img_mean_std[index] = [img_stack.mean(), img_stack.std()]
        spec_mean_std[index] = [spec_stack.mean(), spec_stack.std()]
        
        db.put_samples({'img': img_stack,
                        'spec': spec_stack,
                        'fid_pars': fids,
                        'id': ids,
                        'SNR': SNR})
        t = round(time.time() - start, 2)
        
        print(f'folder {folder} complete, {t} seconds')
# Out:
# folder 1 complete, 15.44 seconds
# folder 2 complete, 16.07 seconds
# folder 3 complete, 16.13 seconds
# folder 4 complete, 15.07 seconds
# folder 5 complete, 16.16 seconds
# folder 6 complete, 16.11 seconds
# folder 7 complete, 16.12 seconds
# folder 8 complete, 18.35 seconds
# folder 9 complete, 17.39 seconds
# folder 10 complete, 17.73 seconds
# folder 11 complete, 18.65 seconds
# folder 12 complete, 27.13 seconds
# folder 13 complete, 18.74 seconds
# folder 14 complete, 26.72 seconds
# folder 15 complete, 26.71 seconds
# folder 16 complete, 26.89 seconds
# folder 17 complete, 27.39 seconds
# folder 18 complete, 18.89 seconds
# folder 19 complete, 19.09 seconds
# folder 20 complete, 26.77 seconds
# folder 21 complete, 19.13 seconds
# folder 22 complete, 18.96 seconds
# folder 23 complete, 18.92 seconds
# folder 24 complete, 18.62 seconds
# folder 25 complete, 27.41 seconds
# folder 26 complete, 18.97 seconds
# folder 27 complete, 18.92 seconds
# folder 28 complete, 27.57 seconds
# ...

# %% [markdown]
# ### Create testing database

# %%
n = 5000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/test_data_5m/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_test_5m.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/databases/test_database_5m'
samples = pd.read_csv(samp_dir)
samples = pd.read_csv(samp_dir)
for i, values in enumerate(par_ranges.values()):
    samples.iloc[:, i+1] = normalize('-11', samples.iloc[:, i+1], values)
samples.to_csv('/xdisk/timeifler/wxs0703/kl_nn/samples/normalized/samples_test_5m.csv', index=False)

with px.Writer(dirpath=save_dir, map_size_limit=200000, ram_gb_limit=8) as db:
    
    for index in range(100):
        start = time.time()
        folder = index+1
        img_stack = np.full((n, 1, 48, 48), 0.)
        spec_stack = np.full((n, 1, 3, 64), 0.)
        start_id = index*n
        file_id = index*n
        ids = np.arange(start_id, start_id+n, dtype=np.uint64)
        SNR = SNR_test[ids]
        fids = np.array(samples.iloc[ids])[:, 1:]

        for i in range(n):
            
            ID = file_id + i

            with fits.open(join(data_dir, f'temp_{folder}/testing_{ID}.fits')) as hdu:

                img = hdu[4].data
                img_wnoise = add_noise(img, SNR[i])
                img_stack[i, 0] = img_wnoise
                
                specs = np.full((3, 64), 0.)
                for k in range(3):
                    spec = hdu[k+1].data
                    spec_wnoise = add_noise(spec, SNR[i])
                    specs[k, :spec.shape[0]] = spec_wnoise
                spec_stack[i, 0] = specs
        
        if index == 0:
            img_mean, img_std = (img_stack.mean(), img_stack.std())
            spec_mean, spec_std = (spec_stack.mean(), spec_stack.std())
        
        img_stack = normalize('std', img_stack, (img_mean, img_std))
        spec_stack = normalize('std', spec_stack, (spec_mean, spec_std))
        
        db.put_samples({'img': img_stack,
                        'spec': spec_stack,
                        'fid_pars': fids,
                        'id': ids,
                        'SNR': SNR})
        t = round(time.time() - start, 2)
        
        print(f'folder {folder} complete, {t} seconds')
# Out:
# folder 1 complete, 19.1 seconds
# folder 2 complete, 19.16 seconds
# folder 3 complete, 27.48 seconds
# folder 4 complete, 19.14 seconds
# folder 5 complete, 19.06 seconds
# folder 6 complete, 19.23 seconds
# folder 7 complete, 27.83 seconds
# folder 8 complete, 19.3 seconds
# folder 9 complete, 27.79 seconds
# folder 10 complete, 19.28 seconds
# folder 11 complete, 19.46 seconds
# folder 12 complete, 27.72 seconds
# folder 13 complete, 27.34 seconds
# folder 14 complete, 19.16 seconds
# folder 15 complete, 19.15 seconds
# folder 16 complete, 19.19 seconds
# folder 17 complete, 19.4 seconds
# folder 18 complete, 27.74 seconds
# folder 19 complete, 27.84 seconds
# folder 20 complete, 19.73 seconds
# folder 21 complete, 19.46 seconds
# folder 22 complete, 19.19 seconds
# folder 23 complete, 19.1 seconds
# folder 24 complete, 19.35 seconds
# folder 25 complete, 19.33 seconds
# folder 26 complete, 19.38 seconds
# folder 27 complete, 27.88 seconds
# folder 28 complete, 19.61 seconds
# ...

# %% [markdown]
# #### Code to test if database is generated properly

# %%
save_dir = '/data/wxs0703/kl-nn/databases/train_database_5m'

# %%
save_dir = '/data/wxs0703/kl-nn/databases/test_database_5m'

# %%
with px.Reader(save_dir) as db:
    img = db[-10000]['img'][0]
    spec = db[-10000]['spec'][0]
    fid = db[-10000]['fid_pars']

# %%
with px.Reader(save_dir) as db:
    new_db = db[:100]

# %%
print(new_db[:][:]['img'].shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(new_db[:][:]['img'].shape)
#
# TypeError: list indices must be integers or slices, not str

# %%
print(new_db[10]['img'])
# Out:
# [[[-0.25833462 -0.13882484 -0.21627868 ... -0.28366242 -0.24061721
#    -0.20181917]
#   [-0.3947339  -0.17789182 -0.34903202 ... -0.25704555 -0.39184101
#    -0.22338237]
#   [-0.23149818 -0.3314697  -0.07161869 ... -0.4684647  -0.46202852
#    -0.47179877]
#   ...
#   [-0.34362412 -0.54357157 -0.38592837 ... -0.14507367 -0.25252138
#    -0.2041619 ]
#   [-0.25365069 -0.42412715 -0.20063558 ...  0.01629326 -0.34693055
#    -0.13633093]
#   [-0.21073448 -0.27088015 -0.2365317  ... -0.36065325 -0.18947036
#     0.00799624]]]

# %%
fid
# Out:
# array([0.9249619 , 0.61727588, 0.433255  , 0.334845  , 0.815635  ,
#        0.264305  ])

# %%
plt.imshow(img)

# %%
plt.plot(spec[0])
