# %%
from os.path import join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sample_root = "/ocean/projects/phy250048p/shared/samples"
samples = pd.read_csv(join(sample_root, "samples_small_10k_mirror.csv"))

# %%
plt.hist2d(samples['g1'], samples['g2'], bins=100, range=[[-0.11, 0.11], [-0.11, 0.11]], cmap='viridis')
plt.show()
