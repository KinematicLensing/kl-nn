# %%
from __future__ import print_function
from os.path import join
import time

import numpy as np
import pandas as pd
import pyxis as px
from astropy.io import fits

# %%
def normalize(samples):
    for par, values in samples.items():
        if par in par_ranges.keys():
            low, high = par_ranges[par]
            values -= low
            values /= high-low

# %%
par_ranges = \
{
    'g1': [-0.5, 0.5],
    'g2': [-0.5, 0.5],
    'sin_theta': [-1, 1],
    'cos_theta': [-1, 1],
    'sini': [0, 1],
    'v0': [-30, 30],
    'vcirc': [60, 540],
    'rscale': [0.1, 10],
    'hlr': [0.1, 5],
}

# %%
n = 4000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_massive/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_massive.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_massive/train_database_sincos'
samples = pd.read_csv(samp_dir)
samples.insert(3, 'sin_theta', np.sin(samples['theta_int']))
samples.insert(4, 'cos_theta', np.cos(samples['theta_int']))
samples = samples.drop('theta_int', axis='columns')
samples.to_csv('/xdisk/timeifler/wxs0703/kl_nn/samples/samples_massive_sincos.csv', index=False)

# %%
n = 4000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_massive/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_massive_sincos.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_massive/train_database_sincos'
samples = pd.read_csv(samp_dir)
normalize(samples)

with px.Writer(dirpath=save_dir, map_size_limit=200000, ram_gb_limit=8) as db:
    
    for index in range(250):
        start = time.time()
        folder = index+1
        img_stack = np.full((n, 1, 48, 48), 0.)
        spec_stack = np.full((n, 1, 3, 64), 0.)
        fids = np.full((n, 9), 0.)
        start_id = index*n
        ids = np.arange(start_id, start_id+n, dtype=np.uint64)

        for i in range(n):
            
            ID = start_id + i

            with fits.open(join(data_dir, f'temp_{folder}/training_{ID}.fits')) as hdu:

                img = hdu[7].data
                img /= np.max(img)
                img_stack[i, 0] = img

                specs = np.full((3, 64), 0.)
                for j in range(3):
                    spec = hdu[2*j+1].data
                    specs[j, :spec.shape[0]] = spec
                specs /= np.max(specs)
                spec_stack[i, 0] = specs

                fids[i] = np.array(samples.iloc[ID])[1:]
                
        db.put_samples({'img': img_stack,
                        'spec': spec_stack,
                        'fid_pars': fids,
                        'id': ids})
        t = round(time.time() - start, 2)
        
        print(f'folder {folder} complete, {t} seconds')
# Out:
# folder 1 complete, 21.74 seconds
# folder 2 complete, 21.85 seconds
# folder 3 complete, 22.05 seconds
# folder 4 complete, 23.62 seconds
# folder 5 complete, 22.82 seconds
# folder 6 complete, 29.29 seconds
# folder 7 complete, 22.49 seconds
# folder 8 complete, 22.73 seconds
# folder 9 complete, 22.13 seconds
# folder 10 complete, 23.61 seconds
# folder 11 complete, 23.71 seconds
# folder 12 complete, 22.06 seconds
# folder 13 complete, 21.36 seconds
# folder 14 complete, 22.22 seconds
# folder 15 complete, 21.89 seconds
# folder 16 complete, 31.22 seconds
# folder 17 complete, 23.0 seconds
# folder 18 complete, 22.47 seconds
# folder 19 complete, 22.71 seconds
# folder 20 complete, 21.85 seconds
# folder 21 complete, 21.41 seconds
# folder 22 complete, 20.02 seconds
# folder 23 complete, 20.71 seconds
# folder 24 complete, 21.21 seconds
# folder 25 complete, 22.51 seconds
# folder 26 complete, 22.69 seconds
# folder 27 complete, 22.76 seconds
# folder 28 complete, 21.66 seconds
# folder 29 complete, 22.0 seconds
# folder 30 complete, 22.49 seconds
# folder 31 complete, 21.81 seconds
# folder 32 complete, 31.02 seconds
# folder 33 complete, 23.75 seconds
# folder 34 complete, 30.93 seconds
# folder 35 complete, 22.52 seconds
# folder 36 complete, 23.12 seconds
# folder 37 complete, 22.41 seconds
# folder 38 complete, 21.21 seconds
# folder 39 complete, 22.89 seconds
# folder 40 complete, 23.65 seconds
# folder 41 complete, 22.74 seconds
# folder 42 complete, 22.63 seconds
# folder 43 complete, 23.02 seconds
# folder 44 complete, 23.89 seconds
# folder 45 complete, 24.07 seconds
# folder 46 complete, 24.07 seconds
# folder 47 complete, 22.55 seconds
# folder 48 complete, 22.43 seconds
# folder 49 complete, 24.08 seconds
# folder 50 complete, 23.03 seconds
# folder 51 complete, 21.78 seconds
# folder 52 complete, 23.77 seconds
# folder 53 complete, 21.15 seconds
# folder 54 complete, 23.0 seconds
# folder 55 complete, 23.83 seconds
# folder 56 complete, 23.7 seconds
# folder 57 complete, 23.48 seconds
# folder 58 complete, 23.93 seconds
# folder 59 complete, 24.26 seconds
# folder 60 complete, 22.6 seconds
# folder 61 complete, 24.61 seconds
# folder 62 complete, 22.96 seconds
# folder 63 complete, 23.41 seconds
# folder 64 complete, 22.23 seconds
# folder 65 complete, 22.31 seconds
# folder 66 complete, 23.13 seconds
# folder 67 complete, 22.75 seconds
# folder 68 complete, 21.31 seconds
# folder 69 complete, 21.47 seconds
# folder 70 complete, 22.88 seconds
# folder 71 complete, 21.43 seconds
# folder 72 complete, 22.93 seconds
# folder 73 complete, 21.19 seconds
# folder 74 complete, 22.94 seconds
# folder 75 complete, 21.97 seconds
# folder 76 complete, 22.77 seconds
# folder 77 complete, 22.6 seconds
# folder 78 complete, 22.6 seconds
# folder 79 complete, 22.78 seconds
# folder 80 complete, 28.37 seconds
# folder 81 complete, 22.2 seconds
# folder 82 complete, 22.13 seconds
# folder 83 complete, 22.67 seconds
# folder 84 complete, 20.21 seconds
# folder 85 complete, 22.13 seconds
# folder 86 complete, 22.42 seconds
# folder 87 complete, 21.86 seconds
# folder 88 complete, 22.92 seconds
# folder 89 complete, 23.17 seconds
# folder 90 complete, 21.41 seconds
# folder 91 complete, 21.4 seconds
# folder 92 complete, 22.34 seconds
# folder 93 complete, 22.53 seconds
# folder 94 complete, 23.41 seconds
# folder 95 complete, 21.55 seconds
# folder 96 complete, 23.0 seconds
# folder 97 complete, 29.81 seconds
# folder 98 complete, 30.57 seconds
# folder 99 complete, 19.91 seconds
# folder 100 complete, 21.65 seconds
# folder 101 complete, 22.34 seconds
# folder 102 complete, 21.68 seconds
# folder 103 complete, 21.24 seconds
# folder 104 complete, 21.67 seconds
# folder 105 complete, 30.44 seconds
# folder 106 complete, 22.19 seconds
# folder 107 complete, 31.08 seconds
# folder 108 complete, 22.66 seconds
# folder 109 complete, 23.74 seconds
# folder 110 complete, 23.26 seconds
# folder 111 complete, 23.2 seconds
# folder 112 complete, 20.58 seconds
# folder 113 complete, 22.42 seconds
# folder 114 complete, 19.71 seconds
# folder 115 complete, 30.27 seconds
# folder 116 complete, 28.51 seconds
# folder 117 complete, 22.75 seconds
# folder 118 complete, 21.94 seconds
# folder 119 complete, 21.69 seconds
# folder 120 complete, 21.54 seconds
# folder 121 complete, 22.89 seconds
# folder 122 complete, 23.09 seconds
# folder 123 complete, 22.68 seconds
# folder 124 complete, 23.52 seconds
# folder 125 complete, 30.36 seconds
# folder 126 complete, 23.8 seconds
# folder 127 complete, 23.83 seconds
# folder 128 complete, 21.91 seconds
# folder 129 complete, 20.64 seconds
# folder 130 complete, 23.33 seconds
# folder 131 complete, 21.89 seconds
# folder 132 complete, 31.07 seconds
# folder 133 complete, 22.5 seconds
# folder 134 complete, 22.44 seconds
# folder 135 complete, 22.12 seconds
# folder 136 complete, 22.85 seconds
# folder 137 complete, 22.67 seconds
# folder 138 complete, 21.65 seconds
# folder 139 complete, 22.91 seconds
# folder 140 complete, 21.35 seconds
# folder 141 complete, 22.09 seconds
# folder 142 complete, 22.9 seconds
# folder 143 complete, 22.24 seconds
# folder 144 complete, 20.08 seconds
# folder 145 complete, 21.97 seconds
# folder 146 complete, 23.67 seconds
# folder 147 complete, 21.52 seconds
# folder 148 complete, 22.62 seconds
# folder 149 complete, 23.41 seconds
# folder 150 complete, 22.14 seconds
# folder 151 complete, 22.33 seconds
# folder 152 complete, 22.79 seconds
# folder 153 complete, 23.06 seconds
# folder 154 complete, 22.21 seconds
# folder 155 complete, 29.38 seconds
# folder 156 complete, 29.49 seconds
# folder 157 complete, 30.25 seconds
# folder 158 complete, 21.05 seconds
# folder 159 complete, 20.72 seconds
# folder 160 complete, 22.76 seconds
# folder 161 complete, 23.11 seconds
# folder 162 complete, 22.57 seconds
# folder 163 complete, 22.35 seconds
# folder 164 complete, 23.44 seconds

# %%
n = 4000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/test_data/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_test_sincos.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/test_data/test_database_sincos'
samples = pd.read_csv(samp_dir)
normalize(samples)
with px.Writer(dirpath=save_dir, map_size_limit=200000, ram_gb_limit=8) as db:
    
    for index in range(25):
        start = time.time()
        folder = index+1
        img_stack = np.full((n, 1, 48, 48), 0.)
        spec_stack = np.full((n, 1, 3, 64), 0.)
        fids = np.full((n, 9), 0.)
        start_id = index*n
        ids = np.arange(start_id, start_id+n, dtype=np.uint64)

        for i in range(n):
            
            ID = start_id + i

            with fits.open(join(data_dir, f'temp_{folder}/testing_{ID}.fits')) as hdu:

                img = hdu[7].data
                img /= np.max(img)
                img_stack[i, 0] = img

                specs = np.full((3, 64), 0.)
                for j in range(3):
                    spec = hdu[2*j+1].data
                    specs[j, :spec.shape[0]] = spec
                specs /= np.max(specs)
                spec_stack[i, 0] = specs

                fids[i] = np.array(samples.iloc[ID])[1:]
                
        db.put_samples({'img': img_stack,
                        'spec': spec_stack,
                        'fid_pars': fids,
                        'id': ids})
        t = round(time.time() - start, 2)
        
        print(f'folder {folder} complete, {t} seconds')

# %%
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_massive/train_database'

# %%
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/test_data/test_database'

# %%
with px.Reader(save_dir) as db:
    print(db)
# Out:
# pyxis.Reader
# Location:		'/xdisk/timeifler/wxs0703/kl_nn/test_data/test_database'
# Number of samples:	100000
# Data keys (0th sample):
# 	'img' <- dtype: float64, shape: (1, 48, 48)
# 	'spec' <- dtype: float64, shape: (1, 3, 64)
# 	'fid_pars' <- dtype: float64, shape: (8,)
# 	'id' <- dtype: uint64, shape: ()
