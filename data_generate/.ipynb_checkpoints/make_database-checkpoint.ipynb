# %%
from __future__ import print_function
from os.path import join
import time

import numpy as np
import pandas as pd
import pyxis as px
from astropy.io import fits
import matplotlib.pyplot as plt

# %% [markdown]
# #### Code exploring lognormal distribution for SNR, not used

# %%
mu, sigma = 4.5, 1.
s = np.random.lognormal(mu, sigma, 10000)
s = s[(s <= 500) & (s >= 20)]
print(s.shape)
# Out:
# (8911,)

# %%
count, bins, ignored = plt.hist(s, 100, density=True, align='mid')
x = np.linspace(min(bins), max(bins), 10000)
pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2))
       / (x * sigma * np.sqrt(2 * np.pi)))
plt.plot(x, pdf, linewidth=2, color='r')
plt.axis('tight')
plt.show()

# %%
SNR_train = np.linspace(20., 250., int(1e6))
np.random.shuffle(SNR_train)
SNR_test = np.linspace(20., 250., int(1e5))
np.random.shuffle(SNR_test)

# %% [markdown]
# #### Find range of noise to normalize over

# %%
n = 4000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/test_data/'
mins = np.empty((100000,), dtype=np.float64)
maxs = np.empty((100000,), dtype=np.float64)
for index in range(25):
    folder = index+1
    start_id = index*n
    for i in range(n):
        ID = start_id + i
        with fits.open(join(data_dir, f'temp_{folder}/testing_{ID}.fits')) as hdu:
            data = np.concatenate((hdu[1].data + hdu[2].data, hdu[3].data + hdu[4].data, hdu[5].data + hdu[6].data))
            mins[ID] = np.min(data)
            maxs[ID] = np.max(data)
    print(f'Folder {folder} complete')
# Out:
# Folder 1 complete
# Folder 2 complete
# Folder 3 complete
# Folder 4 complete
# Folder 5 complete
# Folder 6 complete
# Folder 7 complete
# Folder 8 complete
# Folder 9 complete
# Folder 10 complete
# Folder 11 complete
# Folder 12 complete
# Folder 13 complete
# Folder 14 complete
# Folder 15 complete
# Folder 16 complete
# Folder 17 complete
# Folder 18 complete
# Folder 19 complete
# Folder 20 complete
# Folder 21 complete
# Folder 22 complete
# Folder 23 complete
# Folder 24 complete
# Folder 25 complete

# %%
total = np.concatenate((maxs, mins))
print(np.min(total))
print(np.max(total))
# Out:
# -179.40306021006285
# 184.83903049721658

# %% [markdown]
# ### Start here to create database

# %%
def normalize(samples):
    for par, values in samples.items():
        if par in par_ranges.keys():
            low, high = par_ranges[par]
            values -= low
            values /= high-low

# %%
def add_noise(data, SNR):
    noise = np.random.normal(0, 1, data.shape)
    segmask = data > 0.1*np.max(data)
    target = np.sum(data[segmask])/SNR
    noise *= target/np.sqrt(np.sum(noise[segmask]**2))
    return data + noise

# %%
par_ranges = \
{
    'g1': [-0.1, 0.1],
    'g2': [-0.1, 0.1],
    'theta_int': [-np.pi, np.pi],
    'sini': [0, 1],
    'v0': [-30, 30],
    'vcirc': [60, 540],
    'rscale': [0.1, 10],
    'hlr': [0.1, 5],
}

img_noise_range = [-100, 150]
spec_noise_range = [-250, 250]

# %%
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_low_g/'
with fits.open(join(data_dir, f'temp_{1}/training_{0}.fits')) as hdu:

    img = hdu[7].data
    img_wnoise = add_noise(img, 15)

    specs = np.full((3, 64), 0.)
    for j in range(3):
        spec = hdu[2*j+1].data
        spec_wnoise = add_noise(spec, 15)
        specs[j, :spec.shape[0]] = spec_wnoise

# %%
plt.imshow(img_wnoise)

# %%
plt.plot(specs[0])

# %% [markdown]
# ### Create training database

# %%
n = 4000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_train_low_g_1m.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data/train_database_random_SNR'
samples = pd.read_csv(samp_dir)
normalize(samples)

with px.Writer(dirpath=save_dir, map_size_limit=200000, ram_gb_limit=8) as db:
    
    for index in range(250):
        start = time.time()
        folder = index+1
        img_stack = np.full((n, 1, 48, 48), 0.)
        spec_stack = np.full((n, 1, 3, 64), 0.)
        start_id = index*n
        file_id = index*n
        ids = np.arange(start_id, start_id+n, dtype=np.uint64)
        SNR = SNR_train[ids]
        fids = np.array(samples.iloc[ids])[:, [1, 2, 4, 5, 6, 7]]
        print(ids.shape, SNR.shape, fids.shape)

        for i in range(n):
            
            ID = file_id + i

            with fits.open(join(data_dir, f'temp_{folder}/training_{ID}.fits')) as hdu:

                img = hdu[7].data
                img_wnoise = add_noise(img, SNR[i])
                #low, high = img_noise_range
                #img -= low
                #img /= high-low
                img_stack[i, 0] = img_wnoise
                
                specs = np.full((3, 64), 0.)
                for k in range(3):
                    spec = hdu[2*k+1].data
                    spec_wnoise = add_noise(spec, SNR[i])
                    specs[k, :spec.shape[0]] = spec_wnoise
                #low, high = spec_noise_range
                #specs -= low
                #specs /= high-low
                spec_stack[i, 0] = specs
                
        db.put_samples({'img': img_stack,
                        'spec': spec_stack,
                        'fid_pars': fids,
                        'id': ids,
                        'SNR': SNR})
        t = round(time.time() - start, 2)
        
        print(f'folder {folder} complete, {t} seconds')
# Out:
# (4000,) (4000,) (6, 9)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:1270, in HDUList._try_while_unread_hdus(self, func, *args, **kwargs)
#    1269 try:
# -> 1270     return func(*args, **kwargs)
#    1271 except Exception:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/header.py:2013, in _BasicHeader.__getitem__(self, key)
#    2012 try:
# -> 2013     return self._cards[key].value
#    2014 except KeyError:
#    2015     # parse the Card and store it
#
# KeyError: 'PCOUNT'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 28
#      24 ID = file_id + i
#      26 with fits.open(join(data_dir, f'temp_{folder}/training_{ID}.fits')) as hdu:
# ---> 28     img = hdu[7].data
#      29     img_wnoise = add_noise(img, SNR[i])
#      30     #low, high = img_noise_range
#      31     #img -= low
#      32     #img /= high-low
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:389, in HDUList.__getitem__(self, key)
#     385 # Originally this used recursion, but hypothetically an HDU with
#     386 # a very large number of HDUs could blow the stack, so use a loop
#     387 # instead
#     388 try:
# --> 389     return self._try_while_unread_hdus(
#     390         super().__getitem__, self._positive_index_of(key)
#     391     )
#     392 except IndexError as e:
#     393     # Raise a more helpful IndexError if the file was not fully read.
#     394     if self._read_all:
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:1272, in HDUList._try_while_unread_hdus(self, func, *args, **kwargs)
#    1270     return func(*args, **kwargs)
#    1271 except Exception:
# -> 1272     if self._read_next_hdu():
#    1273         continue
#    1274     else:
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:1314, in HDUList._read_next_hdu(self)
#    1311             offset = last._data_offset + last._data_size
#    1312             fileobj.seek(offset, os.SEEK_SET)
# -> 1314     hdu = _BaseHDU.readfrom(fileobj, **kwargs)
#    1315 except EOFError:
#    1316     self._read_all = True
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/base.py:365, in _BaseHDU.readfrom(cls, fileobj, checksum, ignore_missing_end, **kwargs)
#     362 if not isinstance(fileobj, _File):
#     363     fileobj = _File(fileobj)
# --> 365 hdu = cls._readfrom_internal(
#     366     fileobj, checksum=checksum, ignore_missing_end=ignore_missing_end, **kwargs
#     367 )
#     369 # If the checksum had to be checked the data may have already been read
#     370 # from the file, in which case we don't want to seek relative
#     371 fileobj.seek(hdu._data_offset + hdu._data_size, os.SEEK_SET)
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/base.py:505, in _BaseHDU._readfrom_internal(cls, data, header, checksum, ignore_missing_end, **kwargs)
#     502             del new_kwargs[key]
#     504 try:
# --> 505     hdu = cls(data=DELAYED, header=header, **new_kwargs)
#     506 except TypeError:
#     507     # This may happen because some HDU class (e.g. GroupsHDU) wants
#     508     # to set a keyword on the header, which is not possible with the
#    (...)
#     511     # this case we build a full Header and try again to create the
#     512     # HDU object.
#     513     if isinstance(header, _BasicHeader):
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/image.py:1238, in ImageHDU.__init__(self, data, header, name, do_not_scale_image_data, uint, scale_back, ver)
#    1193 """
#    1194 Construct an image HDU.
#    1195
#    (...)
#    1233     (default: None)
#    1234 """
#    1235 # This __init__ currently does nothing differently from the base class,
#    1236 # and is only explicitly defined for the docstring.
# -> 1238 super().__init__(
#    1239     data=data,
#    1240     header=header,
#    1241     name=name,
#    1242     do_not_scale_image_data=do_not_scale_image_data,
#    1243     uint=uint,
#    1244     scale_back=scale_back,
#    1245     ver=ver,
#    1246 )
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/image.py:121, in _ImageBaseHDU.__init__(self, data, header, do_not_scale_image_data, uint, scale_back, ignore_blank, **kwargs)
#     119 self._bitpix = self._header.get("BITPIX")
#     120 self._gcount = self._header.get("GCOUNT", 1)
# --> 121 self._pcount = self._header.get("PCOUNT", 0)
#     122 self._blank = None if ignore_blank else self._header.get("BLANK")
#     123 self._verify_blank()
#
# File ~/.conda/envs/kl-nn/lib/python3.9/_collections_abc.py:763, in Mapping.get(self, key, default)
#     761 'D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.'
#     762 try:
# --> 763     return self[key]
#     764 except KeyError:
#     765     return default
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/header.py:2018, in _BasicHeader.__getitem__(self, key)
#    2016 cardstr = self._raw_cards[key]
#    2017 self._cards[key] = card = Card.fromstring(cardstr)
# -> 2018 return card.value
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/card.py:293, in Card.value(self)
#     291     value = self._value
#     292 elif self._valuestring is not None or self._image:
# --> 293     value = self._value = self._parse_value()
#     294 else:
#     295     if self._keyword == "":
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/card.py:772, in Card._parse_value(self)
#     770 elif m.group("strg") is not None:
#     771     value = re.sub("''", "'", m.group("strg"))
# --> 772 elif m.group("numr") is not None:
#     773     #  Check for numbers with leading 0s.
#     774     numr = self._number_NFSC_RE.match(m.group("numr"))
#     775     digt = translate(numr.group("digt"), FIX_FP_TABLE2, " ")
#
# KeyboardInterrupt:

# %% [markdown]
# ### Create testing database

# %%
n = 4000
nreal = 5
SNR = [20, 30, 50, 80, 120]
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/test_data_low_g/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_test_low_g.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/test_data_low_g/test_database_5noise_all'
samples = pd.read_csv(samp_dir)
normalize(samples)

#minmax = np.full((50, 4), 0.)

with px.Writer(dirpath=save_dir, map_size_limit=200000, ram_gb_limit=8) as db:
    
    for index in range(5):
        start = time.time()
        folder = index+1
        img_stack = np.full((n*nreal, 1, 48, 48), 0.)
        spec_stack = np.full((n*nreal, 1, 3, 64), 0.)
        fids = np.full((n*nreal, 8), 0.)
        start_id = index*n*nreal
        file_id = index*n
        ids = np.arange(start_id, start_id+n*nreal, dtype=np.uint64)

        for i in range(n):
            
            ID = file_id + i

            with fits.open(join(data_dir, f'temp_{folder}/testing_{ID}.fits')) as hdu:

                img = hdu[7].data
                for j in range(nreal):
                    img_wnoise = add_noise(img, SNR[j])
                    #low, high = img_noise_range
                    #img -= low
                    #img /= high-low
                    img_stack[i*nreal+j, 0] = img_wnoise
                    
                    specs = np.full((3, 64), 0.)
                    for k in range(3):
                        spec = hdu[2*k+1].data
                        spec_wnoise = add_noise(spec, SNR[j])
                        specs[k, :spec.shape[0]] = spec_wnoise
                    #low, high = spec_noise_range
                    #specs -= low
                    #specs /= high-low
                    spec_stack[i*nreal+j, 0] = specs

                    fids[i*nreal+j] = np.array(samples.iloc[ID])[1:]
        
        #minmax[index] = [np.max(img_stack), np.min(img_stack), np.max(spec_stack), np.min(spec_stack)]
        #print(minmax[index])
                
        db.put_samples({'img': img_stack,
                        'spec': spec_stack,
                        'fid_pars': fids,
                        'id': ids})
        t = round(time.time() - start, 2)
        
        print(f'folder {folder} complete, {t} seconds')

#np.save('minmax_train', minmax)
# Out:
# folder 1 complete, 35.01 seconds
# folder 2 complete, 40.9 seconds
# folder 3 complete, 37.22 seconds
# folder 4 complete, 46.37 seconds
# folder 5 complete, 37.04 seconds

# %% [markdown]
# #### Testing code to show if database is generated properly

# %%
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_low_g/train_database_5noise_all'

# %%
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/test_data/test_database_noise'

# %%
with px.Reader(save_dir) as db:
    img = db[4]['img'][0]
    spec = db[1]['spec'][0]
    fid = db[1]['fid_pars']

# %%
fid
# Out:
# array([0.62723383, 0.52546424, 0.1705275 , 0.1468475 , 0.5504175 ,
#        0.1659375 , 0.0572325 , 0.1715575 ])

# %%
plt.imshow(img)

# %%
plt.plot(spec[0])
