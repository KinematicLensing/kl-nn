# %%
from __future__ import print_function
from os.path import join
import time

import numpy as np
import pandas as pd
import pyxis as px
from astropy.io import fits

# %%
def normalize(samples):
    for par, values in samples.items():
        if par in par_ranges.keys():
            low, high = par_ranges[par]
            values -= low
            values /= high-low

# %%
par_ranges = \
{
    'g1': [-0.5, 0.5],
    'g2': [-0.5, 0.5],
    'theta_int': [-np.pi, np.pi],
    'sini': [0, 1],
    'v0': [-30, 30],
    'vcirc': [60, 540],
    'rscale': [0.1, 10],
    'hlr': [0.1, 5],
}

# %%
n = 4000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_massive/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_massive.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_massive/train_database'
samples = pd.read_csv(samp_dir)
normalize(samples)
with px.Writer(dirpath=save_dir, map_size_limit=200000, ram_gb_limit=2) as db:
    
    for index in range(250):
        start = time.time()
        folder = index+1
        img_stack = np.full((n, 1, 48, 48), 0.)
        spec_stack = np.full((n, 1, 3, 64), 0.)
        fids = np.full((n, 8), 0.)
        start_id = index*n
        ids = np.arange(start_id, start_id+n, dtype=np.uint64)

        for i in range(n):
            
            ID = start_id + i

            with fits.open(join(data_dir, f'temp_{folder}/training_{ID}.fits')) as hdu:

                img = hdu[7].data
                img /= np.max(img)
                img_stack[i, 0] = img

                specs = np.full((3, 64), 0.)
                for j in range(3):
                    spec = hdu[2*j+1].data
                    specs[j, :spec.shape[0]] = spec
                specs /= np.max(specs)
                spec_stack[i, 0] = specs

                fids[i] = np.array(samples.iloc[ID])[1:]
                
        db.put_samples({'img': img_stack,
                        'spec': spec_stack,
                        'fid_pars': fids,
                        'id': ids})
        t = round(time.time() - start, 2)
        
        print(f'folder {folder} complete, {t} seconds')
# Out:
# folder 1 complete, 22.75 seconds
# folder 2 complete, 35.58 seconds
# folder 3 complete, 35.83 seconds
# folder 4 complete, 34.83 seconds
# folder 5 complete, 34.97 seconds
# folder 6 complete, 35.12 seconds
# folder 7 complete, 35.58 seconds
# folder 8 complete, 44.65 seconds
# folder 9 complete, 35.34 seconds
# folder 10 complete, 35.59 seconds
# folder 11 complete, 35.55 seconds
# folder 12 complete, 35.6 seconds
# folder 13 complete, 45.74 seconds
# folder 14 complete, 37.17 seconds
# folder 15 complete, 38.93 seconds
# folder 16 complete, 127.03 seconds
# folder 17 complete, 80.57 seconds
# folder 18 complete, 49.06 seconds
# folder 19 complete, 48.38 seconds
# folder 20 complete, 48.58 seconds
# folder 21 complete, 52.07 seconds
# folder 22 complete, 39.77 seconds
# folder 23 complete, 41.12 seconds
# folder 24 complete, 49.38 seconds
# folder 25 complete, 73.29 seconds
# folder 26 complete, 64.64 seconds
# folder 27 complete, 57.58 seconds
# folder 28 complete, 44.2 seconds
# folder 29 complete, 47.51 seconds
# folder 30 complete, 41.46 seconds
# folder 31 complete, 53.56 seconds
# folder 32 complete, 42.61 seconds
# folder 33 complete, 41.03 seconds
# folder 34 complete, 54.95 seconds
# folder 35 complete, 42.62 seconds
# folder 36 complete, 42.16 seconds
# folder 37 complete, 41.85 seconds
# folder 38 complete, 43.28 seconds
# folder 39 complete, 54.46 seconds
# folder 40 complete, 47.01 seconds
# folder 41 complete, 39.79 seconds
# folder 42 complete, 43.24 seconds
# folder 43 complete, 40.76 seconds
# folder 44 complete, 52.86 seconds
# folder 45 complete, 41.48 seconds
# folder 46 complete, 39.69 seconds
# folder 47 complete, 58.82 seconds
# folder 48 complete, 42.17 seconds
# folder 49 complete, 40.95 seconds
# folder 50 complete, 44.04 seconds
# folder 51 complete, 41.9 seconds
# folder 52 complete, 42.52 seconds
# folder 53 complete, 43.36 seconds
# folder 54 complete, 54.11 seconds
# folder 55 complete, 38.28 seconds
# folder 56 complete, 38.93 seconds
# folder 57 complete, 37.51 seconds
# folder 58 complete, 37.97 seconds
# folder 59 complete, 38.27 seconds
# folder 60 complete, 37.79 seconds
# folder 61 complete, 40.88 seconds
# folder 62 complete, 38.23 seconds
# folder 63 complete, 37.99 seconds
# folder 64 complete, 40.85 seconds
# folder 65 complete, 40.09 seconds
# folder 66 complete, 40.53 seconds
# folder 67 complete, 53.18 seconds
# folder 68 complete, 38.56 seconds
# folder 69 complete, 42.08 seconds
# folder 70 complete, 38.63 seconds
# folder 71 complete, 38.45 seconds
# folder 72 complete, 38.55 seconds
# folder 73 complete, 38.55 seconds
# folder 74 complete, 39.0 seconds
# folder 75 complete, 37.99 seconds
# folder 76 complete, 36.45 seconds
# folder 77 complete, 38.09 seconds
# folder 78 complete, 38.18 seconds
# folder 79 complete, 48.52 seconds
# folder 80 complete, 46.4 seconds
# folder 81 complete, 40.34 seconds
# folder 82 complete, 40.58 seconds
# folder 83 complete, 36.62 seconds
# folder 84 complete, 49.93 seconds
# folder 85 complete, 36.64 seconds
# folder 86 complete, 36.24 seconds
# folder 87 complete, 38.5 seconds
# folder 88 complete, 39.59 seconds
# folder 89 complete, 37.83 seconds
# folder 90 complete, 38.4 seconds
# folder 91 complete, 37.08 seconds
# folder 92 complete, 49.97 seconds
# folder 93 complete, 39.16 seconds
# folder 94 complete, 37.65 seconds
# folder 95 complete, 38.72 seconds
# folder 96 complete, 40.24 seconds
# folder 97 complete, 51.63 seconds
# folder 98 complete, 44.42 seconds
# folder 99 complete, 39.83 seconds
# folder 100 complete, 39.51 seconds
# folder 101 complete, 39.5 seconds
# folder 102 complete, 39.3 seconds
# folder 103 complete, 42.31 seconds
# folder 104 complete, 41.67 seconds
# folder 105 complete, 39.36 seconds
# folder 106 complete, 41.71 seconds
# folder 107 complete, 38.3 seconds
# folder 108 complete, 38.98 seconds
# folder 109 complete, 40.22 seconds
# folder 110 complete, 39.03 seconds
# folder 111 complete, 41.5 seconds
# folder 112 complete, 37.49 seconds
# folder 113 complete, 45.03 seconds
# folder 114 complete, 45.91 seconds
# folder 115 complete, 41.24 seconds
# folder 116 complete, 42.14 seconds
# folder 117 complete, 37.02 seconds
# folder 118 complete, 36.58 seconds
# folder 119 complete, 37.47 seconds
# folder 120 complete, 37.73 seconds
# folder 121 complete, 36.11 seconds
# folder 122 complete, 38.35 seconds
# folder 123 complete, 47.83 seconds
# folder 124 complete, 36.71 seconds
# folder 125 complete, 38.67 seconds
# folder 126 complete, 39.05 seconds
# folder 127 complete, 38.89 seconds
# folder 128 complete, 41.56 seconds
# folder 129 complete, 40.48 seconds
# folder 130 complete, 40.87 seconds
# folder 131 complete, 40.24 seconds
# folder 132 complete, 39.19 seconds
# folder 133 complete, 39.3 seconds
# folder 134 complete, 41.16 seconds
# folder 135 complete, 41.67 seconds
# folder 136 complete, 39.72 seconds
# folder 137 complete, 39.32 seconds
# folder 138 complete, 40.17 seconds
# folder 139 complete, 42.15 seconds
# folder 140 complete, 51.2 seconds
# folder 141 complete, 53.23 seconds
# folder 142 complete, 39.49 seconds
# folder 143 complete, 43.51 seconds
# folder 144 complete, 38.71 seconds
# folder 145 complete, 42.68 seconds
# folder 146 complete, 46.63 seconds
# folder 147 complete, 39.83 seconds
# folder 148 complete, 41.02 seconds
# folder 149 complete, 38.26 seconds
# folder 150 complete, 38.7 seconds
# folder 151 complete, 38.63 seconds
# folder 152 complete, 36.73 seconds
# folder 153 complete, 38.43 seconds
# folder 154 complete, 38.46 seconds
# folder 155 complete, 37.89 seconds
# folder 156 complete, 37.5 seconds
# folder 157 complete, 39.95 seconds
# folder 158 complete, 41.57 seconds
# folder 159 complete, 40.92 seconds
# folder 160 complete, 50.17 seconds
# folder 161 complete, 41.82 seconds
# folder 162 complete, 40.65 seconds
# folder 163 complete, 38.25 seconds
# folder 164 complete, 40.56 seconds
# folder 165 complete, 38.92 seconds
# folder 166 complete, 39.76 seconds
# folder 167 complete, 40.73 seconds
# folder 168 complete, 51.5 seconds
# folder 169 complete, 40.27 seconds
# folder 170 complete, 43.24 seconds
# folder 171 complete, 39.98 seconds
# folder 172 complete, 37.6 seconds
# folder 173 complete, 40.1 seconds
# folder 174 complete, 50.53 seconds
# folder 175 complete, 41.54 seconds
# folder 176 complete, 65.62 seconds
# folder 177 complete, 47.97 seconds
# folder 178 complete, 41.02 seconds
# folder 179 complete, 39.78 seconds
# folder 180 complete, 38.86 seconds
# folder 181 complete, 38.13 seconds
# folder 182 complete, 38.1 seconds
# folder 183 complete, 38.24 seconds
# folder 184 complete, 38.2 seconds
# folder 185 complete, 39.25 seconds
# folder 186 complete, 42.69 seconds
# folder 187 complete, 40.22 seconds
# folder 188 complete, 38.78 seconds
# folder 189 complete, 39.05 seconds
# folder 190 complete, 45.93 seconds
# folder 191 complete, 39.31 seconds
# folder 192 complete, 37.73 seconds
# folder 193 complete, 37.84 seconds
# folder 194 complete, 38.26 seconds
# folder 195 complete, 40.46 seconds
# folder 196 complete, 37.51 seconds
# folder 197 complete, 46.95 seconds
# folder 198 complete, 37.49 seconds
# folder 199 complete, 36.99 seconds
# folder 200 complete, 38.43 seconds
# folder 201 complete, 47.76 seconds
# folder 202 complete, 38.61 seconds
# folder 203 complete, 39.3 seconds
# folder 204 complete, 37.32 seconds
# folder 205 complete, 39.59 seconds
# folder 206 complete, 36.81 seconds
# folder 207 complete, 44.04 seconds
# folder 208 complete, 44.58 seconds
# folder 209 complete, 37.54 seconds
# folder 210 complete, 41.63 seconds
# folder 211 complete, 37.15 seconds
# folder 212 complete, 37.55 seconds
# folder 213 complete, 37.03 seconds
# folder 214 complete, 36.33 seconds
# folder 215 complete, 46.02 seconds
# folder 216 complete, 41.39 seconds
# folder 217 complete, 35.8 seconds
# folder 218 complete, 46.11 seconds
# folder 219 complete, 38.0 seconds
# folder 220 complete, 40.99 seconds
# folder 221 complete, 42.48 seconds
# folder 222 complete, 40.4 seconds
# folder 223 complete, 39.76 seconds
# folder 224 complete, 40.21 seconds
# folder 225 complete, 38.47 seconds
# folder 226 complete, 40.27 seconds
# folder 227 complete, 38.32 seconds
# folder 228 complete, 38.59 seconds
# folder 229 complete, 38.73 seconds
# folder 230 complete, 39.11 seconds
# folder 231 complete, 44.27 seconds
# folder 232 complete, 38.67 seconds
# folder 233 complete, 38.49 seconds
# folder 234 complete, 39.15 seconds
# folder 235 complete, 40.04 seconds
# folder 236 complete, 39.05 seconds
# folder 237 complete, 39.54 seconds
# folder 238 complete, 38.84 seconds
# folder 239 complete, 44.83 seconds
# folder 240 complete, 44.83 seconds
# folder 241 complete, 41.0 seconds
# folder 242 complete, 38.71 seconds
# folder 243 complete, 35.8 seconds
# folder 244 complete, 38.04 seconds
# folder 245 complete, 45.96 seconds
# folder 246 complete, 39.56 seconds
# folder 247 complete, 38.31 seconds
# folder 248 complete, 36.08 seconds
# folder 249 complete, 39.79 seconds
# folder 250 complete, 40.2 seconds

# %%
n = 4000
data_dir = '/xdisk/timeifler/wxs0703/kl_nn/test_data/'
samp_dir = '/xdisk/timeifler/wxs0703/kl_nn/samples/samples_test.csv'
save_dir = '/xdisk/timeifler/wxs0703/kl_nn/train_data_massive/train_database'
samples = pd.read_csv(samp_dir)
normalize(samples)
with px.Writer(dirpath=save_dir, map_size_limit=200000, ram_gb_limit=2) as db:
    
    for index in range(25):
        start = time.time()
        folder = index+1
        img_stack = np.full((n, 1, 48, 48), 0.)
        spec_stack = np.full((n, 1, 3, 64), 0.)
        fids = np.full((n, 8), 0.)
        start_id = index*n
        ids = np.arange(start_id, start_id+n, dtype=np.uint64)

        for i in range(n):
            
            ID = start_id + i

            with fits.open(join(data_dir, f'temp_{folder}/testing_{ID}.fits')) as hdu:

                img = hdu[7].data
                img /= np.max(img)
                img_stack[i, 0] = img

                specs = np.full((3, 64), 0.)
                for j in range(3):
                    spec = hdu[2*j+1].data
                    specs[j, :spec.shape[0]] = spec
                specs /= np.max(specs)
                spec_stack[i, 0] = specs

                fids[i] = np.array(samples.iloc[ID])[1:]
                
        db.put_samples({'img': img_stack,
                        'spec': spec_stack,
                        'fid_pars': fids,
                        'id': ids})
        t = round(time.time() - start, 2)
        
        print(f'folder {folder} complete, {t} seconds')
# Out:
# folder 1 complete, 40.06 seconds
# folder 2 complete, 40.08 seconds
# folder 3 complete, 39.2 seconds
# folder 4 complete, 39.64 seconds
# folder 5 complete, 40.3 seconds
# folder 6 complete, 38.24 seconds
# folder 7 complete, 39.45 seconds
# folder 8 complete, 39.03 seconds
# folder 9 complete, 39.35 seconds
# folder 10 complete, 40.01 seconds
# folder 11 complete, 40.43 seconds
# folder 12 complete, 39.39 seconds
# folder 13 complete, 39.74 seconds
# folder 14 complete, 39.15 seconds
# folder 15 complete, 38.76 seconds
# folder 16 complete, 39.15 seconds
# folder 17 complete, 39.23 seconds
# folder 18 complete, 38.59 seconds
# folder 19 complete, 38.55 seconds
# folder 20 complete, 39.04 seconds
# folder 21 complete, 39.2 seconds
# folder 22 complete, 39.11 seconds
# folder 23 complete, 38.92 seconds
# folder 24 complete, 38.91 seconds
# folder 25 complete, 38.78 seconds
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 22
#      18 for i in range(n):
#      20     ID = start_id + i
# ---> 22     with fits.open(join(data_dir, f'temp_{folder}/testing_{ID}.fits')) as hdu:
#      24         img = hdu[7].data
#      25         img /= np.max(img)
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:222, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     219 if not name:
#     220     raise ValueError(f"Empty filename: {name!r}")
# --> 222 return HDUList.fromfile(
#     223     name,
#     224     mode,
#     225     memmap,
#     226     save_backup,
#     227     cache,
#     228     lazy_load_hdus,
#     229     ignore_missing_simple,
#     230     use_fsspec=use_fsspec,
#     231     fsspec_kwargs=fsspec_kwargs,
#     232     decompress_in_memory=decompress_in_memory,
#     233     **kwargs,
#     234 )
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:486, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     467 @classmethod
#     468 def fromfile(
#     469     cls,
#    (...)
#     477     **kwargs,
#     478 ):
#     479     """
#     480     Creates an `HDUList` instance from a file-like object.
#     481
#    (...)
#     484     documentation for details of the parameters accepted by this method).
#     485     """
# --> 486     return cls._readfrom(
#     487         fileobj=fileobj,
#     488         mode=mode,
#     489         memmap=memmap,
#     490         save_backup=save_backup,
#     491         cache=cache,
#     492         ignore_missing_simple=ignore_missing_simple,
#     493         lazy_load_hdus=lazy_load_hdus,
#     494         **kwargs,
#     495     )
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:1169, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1166 if fileobj is not None:
#    1167     if not isinstance(fileobj, _File):
#    1168         # instantiate a FITS file object (ffo)
# -> 1169         fileobj = _File(
#    1170             fileobj,
#    1171             mode=mode,
#    1172             memmap=memmap,
#    1173             cache=cache,
#    1174             use_fsspec=use_fsspec,
#    1175             fsspec_kwargs=fsspec_kwargs,
#    1176             decompress_in_memory=decompress_in_memory,
#    1177         )
#    1178     # The Astropy mode is determined by the _File initializer if the
#    1179     # supplied mode was None
#    1180     mode = fileobj.mode
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File ~/.conda/envs/kl-nn/lib/python3.9/site-packages/astropy/io/fits/file.py:641, in _File._open_filename(self, filename, mode, overwrite)
#     638 ext = os.path.splitext(self.name)[1]
#     640 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 641     self._file = open(self.name, IO_FITS_MODES[mode])
#     642     self.close_on_error = True
#     644 # Make certain we're back at the beginning of the file
#     645 # BZ2File does not support seek when the file is open for writing, but
#     646 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/xdisk/timeifler/wxs0703/kl_nn/test_data/temp_26/testing_100000.fits'

# %%
with px.Reader(database_dir) as db:
    print(db)
# Out:
# pyxis.Reader
# Location:		'/xdisk/timeifler/wxs0703/kl_nn/test_data/test_database'
# Number of samples:	100000
# Data keys (0th sample):
# 	'img' <- dtype: float64, shape: (1, 48, 48)
# 	'spec' <- dtype: float64, shape: (1, 3, 64)
# 	'fid_pars' <- dtype: float64, shape: (8,)
# 	'id' <- dtype: uint64, shape: ()
